# %% [markdown]
# # Treemaps

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import squarify

# %% [markdown]
# ## Masjid Jamek (Distance 1000 GridSize 10)

# %%
df = pd.read_csv('foursqure_masjid_jamek.csv')
df = df.categories.value_counts().to_frame()
df.reset_index(inplace=True)
df.columns = ['categories', 'count']
df.head()

df = df[df['count'] >= 20]

#Utilise matplotlib to scale our goal numbers between the min and max, then assign this scale to our values.
norm = matplotlib.colors.Normalize(vmin=df['count'].min(), vmax=df['count'].max())
colors = [matplotlib.cm.Blues(norm(value)) for value in df['count']]

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(30, 15)

#Use squarify to plot our data, label it and add colours. We add an alpha layer to ensure black labels show through
squarify.plot(label=df['categories'],sizes=df['count'], color = colors, alpha=.6)
plt.title("Venue Categories",fontsize=23,fontweight="bold")

#Remove our axes and display the plot
plt.axis('off')
plt.show()

# %% [markdown]
# ## Masjid Jamek (Distance 100 GridSize 10)

# %%
df = pd.read_csv('masjid_jamek_d100g10.csv')
df = df.categories.value_counts().to_frame()
df.reset_index(inplace=True)
df.columns = ['categories', 'count']
df.head()

df = df[df['count'] >= 5]

#Utilise matplotlib to scale our goal numbers between the min and max, then assign this scale to our values.
norm = matplotlib.colors.Normalize(vmin=df['count'].min(), vmax=df['count'].max())
colors = [matplotlib.cm.Blues(norm(value)) for value in df['count']]

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(20, 10)

#Use squarify to plot our data, label it and add colours. We add an alpha layer to ensure black labels show through
squarify.plot(label=df['categories'],sizes=df['count'], color = colors, alpha=.6)
plt.title("Venue Categories near Masjid Jamek",fontsize=23,fontweight="bold")

#Remove our axes and display the plot
plt.axis('off')
plt.show()

# %% [markdown]
# ## Petronas Towers (Distance 100 GridSize 10)

# %%
df = pd.read_csv('petronas_towers_d100g10.csv')
df = df.categories.value_counts().to_frame()
df.reset_index(inplace=True)
df.columns = ['categories', 'count']
df.head()

df = df[df['count'] >= 5]

#Utilise matplotlib to scale our goal numbers between the min and max, then assign this scale to our values.
norm = matplotlib.colors.Normalize(vmin=df['count'].min(), vmax=df['count'].max())
colors = [matplotlib.cm.Blues(norm(value)) for value in df['count']]

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(20, 10)

#Use squarify to plot our data, label it and add colours. We add an alpha layer to ensure black labels show through
squarify.plot(label=df['categories'],sizes=df['count'], color = colors, alpha=.6)
plt.title("Venue Categories near Petronas Twin Towers",fontsize=23,fontweight="bold")

#Remove our axes and display the plot
plt.rc('font', size=10)   
plt.axis('off')
plt.show()

# %% [markdown]
# ## National Mosque (Distance 100 GridSize 10)

# %%
df = pd.read_csv('Nat_mosque_d100g10.csv')
df = df.categories.value_counts().to_frame()
df.reset_index(inplace=True)
df.columns = ['categories', 'count']
df.head()

df = df[df['count'] >= 5]

#Utilise matplotlib to scale our goal numbers between the min and max, then assign this scale to our values.
norm = matplotlib.colors.Normalize(vmin=df['count'].min(), vmax=df['count'].max())
colors = [matplotlib.cm.Blues(norm(value)) for value in df['count']]

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(20, 10)

#Use squarify to plot our data, label it and add colours. We add an alpha layer to ensure black labels show through
squarify.plot(label=df['categories'],sizes=df['count'], color = colors, alpha=.6)
plt.title("Venue Categories near the National Mosque",fontsize=23,fontweight="bold")

#Remove our axes and display the plot
plt.rc('font', size=10)   
plt.axis('off')
plt.show()
